# %%
import pandas as pd
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib notebook

# %%
start = datetime.datetime(1980, 1, 1)
end = datetime.datetime(2019, 10, 15)

# %% [markdown]
# ## Real GDP

# %%
real_gdp = web.DataReader("GDPC1", "fred", start, end)

# %%
real_gdp.plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Unemployment Rate

# %%
unemp_rate = web.DataReader("UNRATE", "fred", start, end)

# %%
unemp_rate.plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Federal Funds Rate

# %%
fed_funds = web.DataReader("FEDFUNDS", "fred", start, end)

# %%
fed_funds.plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Consumer Price Index

# %%
cpi = web.DataReader("CPIAUCSL", "fred", start, end)

# %%
cpi.plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## 10Y - 2Y Treasury Spread

# %%
ten_two_spread = web.DataReader("T10Y2Y", "fred", start, end)

# %%
ten_two_spread.plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Average 30Y Fixed Rate Mortgage

# %%
thrty_fixed_mrtg = web.DataReader("MORTGAGE30US", "fred", start, end)

# %%
thrty_fixed_mrtg.plot()
# Out:
# <img src="data:image/png;base64,...">
